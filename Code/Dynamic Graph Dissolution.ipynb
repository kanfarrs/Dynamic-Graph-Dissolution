# %%
from dgd import graph #will have to install: karstnet, pyvista, open3d, kmapper, mplstereonet, kneebow, multiprocess (and maybe others depending on env)
from processDFN import dfn
import os
dfn_path = os.getcwd() + '/data/'

# %% [markdown]
# ## View Discrete Fracture Network

# %%
#view discrete fracture network
dfn(dfn_path).viewDFN()

# %%
#view graph of discrete fracture network
dfn(dfn_path).viewGraph()

# %% [markdown]
# ## run graph dissolution on discrete fracture network

# %%
## run graphDiss
G = dfn(dfn_path).getGraph()
num_years = 10
dt = 1
diss_graph = graph(num_years, dt, G, dfn_path)
grid = diss_graph.graphDiss()
# Out:
# 100%|███████████████████████████████████████████| 11/11 [00:06<00:00,  1.70it/s]

# %%
#diss_graph.gridVideo()
